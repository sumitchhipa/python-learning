# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/data_dividation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data dividation
# df---> x+y
# x---> x_train ,x_test
# y---> y_train ,y_test
import numpy as np
import pandas as pd
df=pd.read_csv("/content/placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
x=df.drop(columns=["placed"])#in[putdata]
y=df["placed"]#target data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
np.round(x_train.describe(),2)
x_train.describe()
# Out:
#             cgpa  resume_score
# count  80.000000     80.000000
# mean    6.949625      6.999500
# std     1.125988      1.010789
# min     5.270000      4.950000
# 25%     5.997500      6.280000
# 50%     6.620000      7.155000
# 75%     8.062500      7.692500
# max     9.310000      9.060000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
np.round(x_train_sc)
type(x_train_sc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-5aa1d3c338ed> in <cell line: 0>()
#       2 sc=StandardScaler()
#       3 x_train_sc=sc.fit_transform(x_train)
# ----> 4 np.round(x_train_sc.describe(),2)
#       5 type(x_train_sc)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
x_train_new=pd.DataFrame(x_train_sc,columns=x_train.columns)
type(x_train_new)
x_train_new.head()
# Out:
#        cgpa  resume_score
# 0 -0.008602     -0.128926
# 1  1.001293     -0.925381
# 2 -0.607389     -0.527154
# 3 -0.044350     -0.089103
# 4  0.992356      2.051369

# %%
df=pd.read_csv("/content/covid_toy.csv")
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()
df['fever']=si.fit_transform(df[['fever']])
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Male':1,'Female':0})
df['cough']=df['cough'].map({'Mild':1,'Strong':2,'Strong':3})
df['city']=df['city'].map({'Delhi':1,'Mumbai':2,'Bangalore':3})
df['has_covid']=df['has_covid'].map({'Positive':1,'Negative':0})
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      1   NaN        NaN
# 1   27       1  100.0      1   1.0        NaN
# 2   42       1  101.0      1   1.0        NaN
# 3   31       0   98.0      1   NaN        NaN
# 4   65       0  101.0      1   2.0        NaN

# %%
x=df.drop(columns=['has_covid'])#impute data
y=df['has_covid']#target data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
#          age  gender   fever  cough   city
# count  80.00   80.00   80.00  80.00  57.00
# mean   42.91    0.41  100.98   1.80   2.19
# std    24.47    0.50    1.93   0.99   0.85
# min     5.00    0.00   98.00   1.00   1.00
# 25%    20.00    0.00  100.00   1.00   1.00
# 50%    42.00    0.00  101.00   1.00   2.00
# 75%    65.00    1.00  102.00   3.00   3.00
# max    84.00    1.00  104.00   3.00   3.00

# %%
df=pd.read_csv("/content/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 21.01    2
# 20.69    2
# 10.33    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
x=df.drop(columns=['total_bill'])#impute data
y=df['total_bill']#target data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
#           tip    size
# count  195.00  195.00
# mean     3.09    2.57
# std      1.43    0.94
# min      1.00    1.00
# 25%      2.00    2.00
# 50%      3.00    2.00
# 75%      3.70    3.00
# max     10.00    6.00

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
np.round(x_train_sc)
type(x_train_sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-1caa5a1c7573> in <cell line: 0>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc=StandardScaler()
# ----> 3 x_train=sc.fit_transform(x_train)
#       4 np.round(x_train_sc)
#       5 type(x_train_sc)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
# normalisation ---> it is converts min or max value 0 and 1
df=pd.read_csv("/content/placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
x=df.drop(columns=["placed"])#in[putdata]
y=df["placed"]

# %%
x_test, y_test, x_train, y_train =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
# count    80.0
# mean      0.5
# std       0.5
# min       0.0
# 25%       0.0
# 50%       0.5
# 75%       1.0
# max       1.0
# Name: placed, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-8b458e69af88> in <cell line: 0>()
# ----> 1 x_train_mn=mn.fit_transform(x_train)
#       2 np.round(x_train_mn)
#       3 type(x_train_mn)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
# ...
