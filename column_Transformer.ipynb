# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/column_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv('/content/covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=['has_covid']),
                                               df['has_covid'],test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 27   33  Female  102.0  Strong      Delhi
# 33   26  Female   98.0    Mild    Kolkata
# 54   60  Female   99.0    Mild     Mumbai
# 57   49  Female   99.0  Strong  Bangalore
# 81   65    Male   99.0    Mild      Delhi
# ..  ...     ...    ...     ...        ...
# 72   83  Female  101.0    Mild    Kolkata
# 85   16  Female  103.0    Mild  Bangalore
# 10   75  Female    NaN    Mild      Delhi
# 84   69  Female   98.0  Strong     Mumbai
# 59    6  Female  104.0    Mild    Kolkata
#
# [80 rows x 5 columns]

# %%
# adding SimpleImputer
si=SimpleImputer()
X_train_fever=si.fit_transform(X_train[['fever']])
X_test_fever=si.fit_transform(X_test[['fever']])#test data
X_train_fever.shape
# Out:
# (80, 1)

# %%
# ordinalencoding-->cough
oe=OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough=oe.fit_transform(X_train[['cough']])
X_test_cough=oe.fit_transform(X_test[['cough']])
X_train_cough.shape
# Out:
# (80, 1)

# %%
#onehotencoding --> gender and city
ohe=OneHotEncoder(drop='first',sparse_output=False)
#
X_train_gender_city=ohe.fit_transform(X_train[['gender','city']])
X_test_gender_city=ohe.fit_transform(X_test[['gender','city']])
X_train_gender_city.shape
# Out:
# (80, 4)

# %%
# extracting age
X_train_age=X_train.drop(columns=
 ['gender','fever','cough','city']).values

# %%
X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed=np.concatenate((X_train_age,X_train_fever,
                                    X_train_gender_city,X_train_cough),axis=1)

# %%
X_train_transformed.shape
# Out:
# (80, 7)

# %%
# by the help of column transformer
from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.preprocessing import OrdinalEncoder
transformer = ColumnTransformer(transformers=[
# 1.  constant 2.approachname 3.columnname
    ('tnf1', SimpleImputer(), ['fever']), # Assuming 'fever' is a numerical feature
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
    ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
], remainder='passthrough')

# %%
transformer.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)

# %%
# pd.get_dummies and OneHotEncoder any two colums

# %%
import numpy as np
import pandas as pd
df1=pd.read_csv('/content/covid_toy.csv')
df1.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
df_dummy = pd.get_dummies(df1, columns=['gender', 'city'], drop_first=True)
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(df1[['gender', 'city']])
encoded_data = enc.transform(df1[['gender', 'city']]).toarray()
encoded_df = pd.DataFrame(encoded_data, columns=enc.get_feature_names_out(['gender', 'city']))
df_onehot = pd.concat([df1, encoded_df], axis=1)

df_onehot.head()
# Out:
#    age  fever cough has_covid  gender_Male  city_Delhi  city_Kolkata  \
# 0   60  103.0  Mild        No         True       False          True
# 1   27  100.0  Mild       Yes         True        True         False
# 2   42  101.0  Mild        No         True        True         False
# 3   31   98.0  Mild        No        False       False          True
# 4   65  101.0  Mild        No        False       False         False
#
#    city_Mumbai
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True

# %%
df_dummy.head()
# Out:
#    age  fever cough has_covid  gender_Male  city_Delhi  city_Kolkata  \
# 0   60  103.0  Mild        No         True       False          True
# 1   27  100.0  Mild       Yes         True        True         False
# 2   42  101.0  Mild        No         True        True         False
# 3   31   98.0  Mild        No        False       False          True
# 4   65  101.0  Mild        No        False       False         False
#
#    city_Mumbai
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
