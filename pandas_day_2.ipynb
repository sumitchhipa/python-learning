# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/pandas_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# for import data from local system
df1=pd.read_csv("/content/covid_toy.csv")
df1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2=pd.read_csv("/content/placement.csv")
df2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df3=pd.read_csv("/content/tips.csv")
df3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df4=pd.read_csv("/content/tips.csv")
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.head(20)
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# 5    84  Female    NaN    Mild  Bangalore       Yes
# 6    14    Male  101.0  Strong  Bangalore        No
# 7    20  Female    NaN  Strong     Mumbai       Yes
# 8    19  Female  100.0  Strong  Bangalore        No
# 9    64  Female  101.0    Mild      Delhi        No
# 10   75  Female    NaN    Mild      Delhi        No
# 11   65  Female   98.0    Mild     Mumbai       Yes
# 12   25  Female   99.0  Strong    Kolkata        No
# 13   64    Male  102.0    Mild  Bangalore       Yes
# 14   51    Male  104.0    Mild  Bangalore        No
# 15   70    Male  103.0  Strong    Kolkata       Yes
# 16   69  Female  103.0    Mild    Kolkata       Yes
# ...

# %%
df2.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
df1.tail()
# bottom data
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df2.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df2.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df2.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df2.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df2.iloc[:3:2]
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 2  8.27          8.86       1

# %%
b=df2.loc[1:3,['cgpa','placed']]
b
# diffrence between loc and iloc methods?
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
a=df2.dtypes
a
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df2.empty
b
# Out:
# False

# %%
c=df2.isnull().sum()
c
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df2.dropna()
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df=pd.read_csv("/content/flipkart.csv")
df
# Out:
#                                         Model Name  Ratings         Reviews  \
# 0                realme GT 6 (Razor Green, 256 GB)      4.5     107 Reviews
# 1    SAMSUNG Galaxy A36 5G (Awesome Black, 128 GB)      4.4      29 Reviews
# 2              vivo T3 Ultra (Frost Green, 256 GB)      4.5     608 Reviews
# 3               vivo T3 Ultra (Lunar Gray, 256 GB)      4.5     608 Reviews
# 4          SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)      4.4     151 Reviews
# 5           realme 14 Pro+ 5G (Suede Grey, 256 GB)      4.4     506 Reviews
# 6               realme GT 6 (Fluid Silver, 256 GB)      4.5     107 Reviews
# 7               realme GT 6 (Fluid Silver, 256 GB)      4.5     311 Reviews
# 8            Nothing Phone (3a) Pro (Grey, 256 GB)      4.5      90 Reviews
# 9                realme GT 6 (Razor Green, 256 GB)      4.5     311 Reviews
# 10              realme GT 6 (Fluid Silver, 512 GB)      4.5     517 Reviews
# ...

# %%
df.head(10)
# Out:
#                                       Model Name  Ratings      Reviews  \
# 0              realme GT 6 (Razor Green, 256 GB)      4.5  107 Reviews
# 1  SAMSUNG Galaxy A36 5G (Awesome Black, 128 GB)      4.4   29 Reviews
# 2            vivo T3 Ultra (Frost Green, 256 GB)      4.5  608 Reviews
# 3             vivo T3 Ultra (Lunar Gray, 256 GB)      4.5  608 Reviews
# 4        SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)      4.4  151 Reviews
# 5         realme 14 Pro+ 5G (Suede Grey, 256 GB)      4.4  506 Reviews
# 6             realme GT 6 (Fluid Silver, 256 GB)      4.5  107 Reviews
# 7             realme GT 6 (Fluid Silver, 256 GB)      4.5  311 Reviews
# 8          Nothing Phone (3a) Pro (Grey, 256 GB)      4.5   90 Reviews
# 9              realme GT 6 (Razor Green, 256 GB)      4.5  311 Reviews
#
#                   Storage                            Screen size  \
# 0  12 GB RAM | 256 GB ROM  17.22 cm (6.78 inch) Full HD+ Display
# ...

# %%
df.tail(5)
# Out:
#                                         Model Name  Ratings      Reviews  \
# 19               realme GT 6 (Razor Green, 512 GB)      4.5  517 Reviews
# 20  SAMSUNG Galaxy S24+ 5G (Cobalt Violet, 256 GB)      4.5  594 Reviews
# 21             vivo V50 5G (Titanium Grey, 256 GB)      4.5  344 Reviews
# 22                  vivo V50 5G (Rose Red, 512 GB)      4.5   93 Reviews
# 23   SAMSUNG Galaxy A36 5G (Awesome Black, 256 GB)      4.4   29 Reviews
#
#                    Storage                            Screen size  \
# 19  16 GB RAM | 512 GB ROM  17.22 cm (6.78 inch) Full HD+ Display
# 20  12 GB RAM | 256 GB ROM   17.02 cm (6.7 inch) Quad HD+ Display
# 21   8 GB RAM | 256 GB ROM            17.2 cm (6.77 inch) Display
# 22  12 GB RAM | 512 GB ROM            17.2 cm (6.77 inch) Display
# 23   8 GB RAM | 256 GB ROM   17.02 cm (6.7 inch) Full HD+ Display
#
#                                     Camera           Battery  \
# 19   50MP + 8MP + 50MP | 32MP Front Camera  5500 mAh Battery
# ...

# %%
df.describe()
# Out:
#          Ratings
# count  24.000000
# mean    4.475000
# std     0.060792
# min     4.300000
# 25%     4.475000
# 50%     4.500000
# 75%     4.500000
# max     4.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model Name        24 non-null     object
#  1   Ratings           24 non-null     float64
#  2   Reviews           24 non-null     object
#  3   Storage           24 non-null     object
#  4   Screen size       24 non-null     object
#  5   Camera            24 non-null     object
#  6   Battery           24 non-null     object
#  7   processor         24 non-null     object
#  8   Warranty          22 non-null     object
#  9   Discounted price  24 non-null     object
#  10  Actual Price      24 non-null     object
#  11  Off               24 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 2.4+ KB

# %%
a=df.isnull
a
# Out:
# <bound method DataFrame.isnull of                                         Model Name  Ratings         Reviews  \
# 0                realme GT 6 (Razor Green, 256 GB)      4.5     107 Reviews
# 1    SAMSUNG Galaxy A36 5G (Awesome Black, 128 GB)      4.4      29 Reviews
# 2              vivo T3 Ultra (Frost Green, 256 GB)      4.5     608 Reviews
# 3               vivo T3 Ultra (Lunar Gray, 256 GB)      4.5     608 Reviews
# 4          SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)      4.4     151 Reviews
# 5           realme 14 Pro+ 5G (Suede Grey, 256 GB)      4.4     506 Reviews
# 6               realme GT 6 (Fluid Silver, 256 GB)      4.5     107 Reviews
# 7               realme GT 6 (Fluid Silver, 256 GB)      4.5     311 Reviews
# 8            Nothing Phone (3a) Pro (Grey, 256 GB)      4.5      90 Reviews
# 9                realme GT 6 (Razor Green, 256 GB)      4.5     311 Reviews
# 10              realme GT 6 (Fluid Silver, 512 GB)      4.5     517 Reviews
# ...

# %%
df.isnull().sum()
# Out:
# Model Name          0
# Ratings             0
# Reviews             0
# Storage             0
# Screen size         0
# Camera              0
# Battery             0
# processor           0
# Warranty            2
# Discounted price    0
# Actual Price        0
# Off                 0
# dtype: int64
