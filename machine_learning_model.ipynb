# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/machine_learning_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # # machine learning---
# # # 1 superwised
# # # 2 unsuperwised
# # # superwises ML
# # a). linear regression model
# # b). logistic Regression model
# # c). descision tree model
# # d). randomForest
# # e). naive bayes
# # d). svm


# # unsupervised ML
# a) pca
# b)kmeans
# c)apriori

# %%
# what does ML model->
# data--> divide(input, target)->>>
# train and test data-->
# machine (x_tyrain,y_train)
# machine(x_test)---> predict---> y_pred
# y_test
# metrics_score(y_test,y_pred)

# %%
# # linear Regression
# input(x)      output(y)
# 1+1          2
# 2+3          5
# 5+6          11
# model([1+1,2+3],[2,5])---> model(5+6)-----?????====15<-----y_pred
# y_test =11
# metrics_score(y_test,y_pred)

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=df.drop(columns='charges')
y=df['charges']
df=pd.get_dummies(df,columns=['sex','smoker','region'])
df
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-14532ef797e0> in <cell line: 0>()
#       1 from sklearn.linear_model import LinearRegression
#       2 model=LinearRegression()
# ----> 3 model.fit(x_train,y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...

# %%
y_pred=model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-77e3652b0a4e> in <cell line: 0>()
# ----> 1 y_pred=model.predict(x_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
#     278         if coef_.ndim == 1:
#
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8085f59827e5> in <cell line: 0>()
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

df = pd.read_csv('/content/insurance.csv')

# Separate features (x) and target (y) BEFORE applying get_dummies
x = df.drop(columns='charges')
y = df['charges']

# Apply one-hot encoding to the features dataframe
x = pd.get_dummies(x, columns=['sex', 'smoker', 'region'], drop_first=True) # Adding drop_first=True to avoid multicollinearity

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Evaluate the model
r2_score(y_test, y_pred)
# Out:
# 0.7623311844057112

# %%
df=pd.read_csv('/content/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=pd.get_dummies(df,columns=['sex','smoker','day','time'])
df
# Out:
#      total_bill   tip  size  sex_Female  sex_Male  smoker_No  smoker_Yes  \
# 0         16.99  1.01     2        True     False       True       False
# 1         10.34  1.66     3       False      True       True       False
# 2         21.01  3.50     3       False      True       True       False
# 3         23.68  3.31     2       False      True       True       False
# 4         24.59  3.61     4        True     False       True       False
# ..          ...   ...   ...         ...       ...        ...         ...
# 239       29.03  5.92     3       False      True       True       False
# 240       27.18  2.00     2        True     False      False        True
# 241       22.67  2.00     2       False      True      False        True
# 242       17.82  1.75     2       False      True       True       False
# 243       18.78  3.00     2        True     False       True       False
#
#      day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  time_Lunch
# ...

# %%
x=df.drop(columns='total_bill')
y=df['total_bill']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 9.88090221, 19.04899818, 25.12291708, 14.91189207, 16.41238508,
#        15.84558189, 16.80589741, 24.44437685, 17.85635817, 25.07700905,
#        13.71183941, 11.83278912, 30.73730171, 24.39839202, 44.8994149 ,
#        17.52613405, 28.80995711, 15.31522768, 14.46326504, 16.24728097,
#        26.24914122, 18.27451728, 22.65052314, 38.09158071, 11.53234878,
#        10.63205298, 23.70816524, 25.25023901, 18.75896345, 20.8915268 ,
#        15.195415  , 32.32782429, 17.46611433, 24.56243736, 28.37645714,
#        11.85122808, 26.83161583, 22.69454354, 21.38150784, 10.63205298,
#        21.62423861, 21.8799889 , 18.4657184 , 17.79622279, 21.26564116,
#        20.0280944 , 22.63023541, 29.2483796 , 16.18539797])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6719006761625261
