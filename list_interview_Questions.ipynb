# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/list_interview_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3]
b = a.copy()
b
# Out:
# [1, 2, 3]

# %%
a = [1, 2, 3]
print(2 in a)
# Out:
# True

# %%
a = [1, 2, 2, 3]
print(a.count(2))
# Out:
# 2

# %%
a = [10, 20, 30]
print(a.index(20))   # 1
# Out:
# 1

# %%
a = [1, 2]
b = [3, 4]
c = a + b
c
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 2, 3]
result = []
for i in a:
    if i not in result:
        result.append(i)

# %%
a = [[1, 2], [3, 4]]

# %%
a = [[1, 2], [3, 4]]
flat = [item for sublist in a for item in sublist]

# %%
for i in [1, 2, 3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
a = [1, 4, 2]
a.sort(reverse=True)

# %%
a = [10, 5, 8]
a.sort()
print(a[-2])
# Out:
# 8
