# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### for installing pandas in jupitor or google colab
# !pip install pandas
# data structres of pandas:
# 1 series ---> it is one dimensional array and it shows only values not columns
# 2 dataframe ---> it is multi dimensional array and it shows values with colum
# !pip install pandas
import pandas as pd
# Use pd.Series with a capital 'S' to create a pandas Series
a = pd.Series([1, 34, 25, 3, 5])
print(a)
# Out:
# ...
# 0     1
# 1    34
# 2    25
# 3     3
# 4     5
# dtype: int64

# %%
# datafeame
import pandas as pd
a={
    "emp_id":[1,2,3,4,5,6,7],
    "emp_name":['sam','ram','ham','king','joy','honey','bobby'],
    "department":['it','sales','IT','operation','hr','it','hr'],
    "salary":[10000,20000,30000,40000,50000,60000,70000],
    "workinghours":[10,20,30,40,50,60,70]
     }
type(a)
df=pd.DataFrame(a)
df
# Out:
#    emp_id emp_name department  salary  workinghours
# 0       1      sam         it   10000            10
# 1       2      ram      sales   20000            20
# 2       3      ham         IT   30000            30
# 3       4     king  operation   40000            40
# 4       5      joy         hr   50000            50
# 5       6    honey         it   60000            60
# 6       7    bobby         hr   70000            70

# %%
# how export dataframe into csv file
df.to_csv("C:\\Users\\sumit\\Music\\OneDrive\\Desktop\\dataframe\\emp_info.csv",index=False)
df
# Out:
#    emp_id emp_name department  salary  workinghours
# 0       1      sam         it   10000            10
# 1       2      ram      sales   20000            20
# 2       3      ham         IT   30000            30
# 3       4     king  operation   40000            40
# 4       5      joy         hr   50000            50
# 5       6    honey         it   60000            60
# 6       7    bobby         hr   70000            70

# %%
# method2/
# go to home page of jupitor
# click on upload
# click on open
# pd.read_csv("filename.csv")
# df=pd.read_csv("cars.csv")
# df
