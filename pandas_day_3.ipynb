# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitchhipa/python-learning/blob/main/pandas_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 15  8.88          5.93       1

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
b=df.loc()
b

# %%
df.iloc()

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.empty
# Out:
# False

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]>

# %%
i=df.ndim
i
# Out:
# 2

# %%
b=df.shape
b
# Out:
# (100, 3)

# %%
d=df.size
d
# Out:
# 300

# %%
e=df.values
e
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
f=df.copy()
f
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
q=df.sort_index()
q
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df["resume_score"]=df['resume_score'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']=df['resume_score'].add(5)
df
# Out:
#     cgpa  resume_score  placed
# 0     12            11       1
# 1     10            10       0
# 2     12            13       1
# 3     10            12       1
# 4     11            12       1
# ..   ...           ...     ...
# 95    10            11       0
# 96    12            12       1
# 97    10            12       0
# 98    12            10       1
# 99    10            11       0
#
# [100 rows x 3 columns]

# %%
df['placed']=df['placed'].add(6)
df
# Out:
#     cgpa  resume_score  placed
# 0     12            11      31
# 1     10            10      30
# 2     12            13      31
# 3     10            12      31
# 4     11            12      31
# ..   ...           ...     ...
# 95    10            11      30
# 96    12            12      31
# 97    10            12      30
# 98    12            10      31
# 99    10            11      30
#
# [100 rows x 3 columns]

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.min()
# Out:
# cgpa             9
# resume_score     9
# placed          30
# dtype: int64

# %%
df.max()
# Out:
# cgpa            13
# resume_score    14
# placed          31
# dtype: int64

# %%
r=df['cgpa'].mean()
r
# Out:
# np.float64(10.47)

# %%
s=df['cgpa'].median()
s
# Out:
# 10.0

# %%
r=df.mean()
r
# Out:
# cgpa            10.47
# resume_score    11.47
# placed          30.50
# dtype: float64

# %%
g=df.filter(items=['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0     12      31
# 1     10      30
# 2     12      31
# 3     10      31
# 4     11      31
# ..   ...     ...
# 95    10      30
# 96    12      31
# 97    10      30
# 98    12      31
# 99    10      30
#
# [100 rows x 2 columns]

# %%
s=df.filter(items=[5,6],axis=0)
s
# Out:
#    cgpa  resume_score  placed
# 5    12            11      31
# 6     9            12      30

# %%
s=df.to_dict()
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
q=df.to_string()
q
# Out:
# '    cgpa  resume_score  placed\n0     12            11      31\n1     10            10      30\n2     12            13      31\n3     10            12      31\n4     11            12      31\n5     12            11      31\n6      9            12      30\n7     10            11      30\n8     10            11      30\n9     11            12      31\n10    10            11      30\n11     9            11      30\n12    10            12      30\n13    12            10      31\n14    11            11      31\n15    12            10      31\n16    12            12      31\n17    11            13      31\n18     9            10      30\n19    10            13      31\n20     9            13      30\n21    10            12      30\n22    10            10      30\n23    10            12      30\n24    12            11      31\n25    11            10      31\n26    10            11      30\n27     9            11      30\n28    11            12      31\n29    10            12      30\n30   
# ...

# %%
e=df.to_csv("/content/placement.csv")
e

# %%
idx=df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label=df.columns[0]
label
# Out:
# 'cgpa'

# %%
p=df.rename(columns={'cgpa':"updated_cgpa","resume_score":"semester_marks"})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             12              11      31
# 1             10              10      30
# 2             12              13      31
# 3             10              12      31
# 4             11              12      31
# ..           ...             ...     ...
# 95            10              11      30
# 96            12              12      31
# 97            10              12      30
# 98            12              10      31
# 99            10              11      30
#
# [100 rows x 3 columns]

# %%
a=df.columns
a
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df['cgpan']=df['cgpa'].astype(int)
df
# here new column crated
# Out:
#     cgpa  resume_score  placed  cgpan
# 0     12            11      31     12
# 1     10            10      30     10
# 2     12            13      31     12
# 3     10            12      31     10
# 4     11            12      31     11
# ..   ...           ...     ...    ...
# 95    10            11      30     10
# 96    12            12      31     12
# 97    10            12      30     10
# 98    12            10      31     12
# 99    10            11      30     10
#
# [100 rows x 4 columns]

# %%
df.drop(columns=['cgpan'])
# Out:
#     cgpa  resume_score  placed
# 0     12            11      31
# 1     10            10      30
# 2     12            13      31
# 3     10            12      31
# 4     11            12      31
# ..   ...           ...     ...
# 95    10            11      30
# 96    12            12      31
# 97    10            12      30
# 98    12            10      31
# 99    10            11      30
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed  cgpan
# 0     12            11      31     12
# 1     10            10      30     10
# 2     12            13      31     12
# 3     10            12      31     10
# 4     11            12      31     11
# ..   ...           ...     ...    ...
# 95    10            11      30     10
# 96    12            12      31     12
# 97    10            12      30     10
# 98    12            10      31     12
# 99    10            11      30     10
#
# [100 rows x 4 columns]

# %%
df['new']=df['cgpa'].where(df['cgpa']>5,other=0)
df
# Out:
# <bound method NDFrame.sample of     cgpa  resume_score  placed  cgpan  new
# 0     12            11      31     12   12
# 1     10            10      30     10   10
# 2     12            13      31     12   12
# 3     10            12      31     10   10
# 4     11            12      31     11   11
# ..   ...           ...     ...    ...  ...
# 95    10            11      30     10   10
# 96    12            12      31     12   12
# 97    10            12      30     10   10
# 98    12            10      31     12   12
# 99    10            11      30     10   10
#
# [100 rows x 5 columns]>

# %%
df.sample(10)
# Out:
#     cgpa  resume_score  placed  cgpan  new
# 20     9            13      30      9    9
# 24    12            11      31     12   12
# 70    11            12      31     11   11
# 81    10            11      30     10   10
# 13    12            10      31     12   12
# 19    10            13      31     10   10
# 42    10            11      31     10   10
# 49     9            11      30      9    9
# 58    10            12      30     10   10
# 21    10            12      30     10   10

# %%
# make notes-concatinating and merging two dataframe
data1={
    "name":["sally","mary",'john'],
    "age":[50,40,30]
}
data2={
    "name":["sally","peter",'mickey'],
    "age":[77,44,22]
}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
newdf=df1.merge(df1,how='outer')
newdf
# Out:
#     name  age
# 0   john   30
# 1   mary   40
# 2  sally   50

# %%
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B','bca','mtech']}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
newdf=pd.concat([df1,df2])
newdf
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur             B
# 2  Dhiraj   12  Allahabad           bca
# 3  Hitesh   52    Kannuaj         mtech

# %%
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B','bca','mtech']}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
# merging the two dataframes based on the common column 'Address'
df=pd.merge(df1,df2, on="Address",how='outer')
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0  Gaurav     22  Allahabad             MCA  Dhiraj     12             bca
# 1    Anuj     32    Kannuaj             Phd  Hitesh     52           mtech
# 2  Princi     24     Kanpur              MA  Ayushi     14               B
# 3     Jai     27     Nagpur             Msc    Abhi     17           Btech
